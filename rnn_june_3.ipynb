# %%
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, SpatialDropout1D
import matplotlib.pyplot as plt

# %%
#RNNs are used in deep learning and in the development of models that simulate neuron activity in the human brain.

#They are especially powerful in use cases where context is critical to predicting an outcome

# %%
data = pd.read_csv("/content/june 3.csv")

data.head()
# Out:
#    Unnamed: 0                                             tweets  \
# 0           0  General News â¢\xa0'I am at a loss â Presid...
# 1           1  '#SheDeyGoLike #MissedThis? More Photos: How M...
# 2           2  '#SheDeyGoLike #MissedThis? More Photos: How M...
# 3           3  General News â¢\xa0'20-year-old student dies ...
# 4           4  General News â¢\xa0'Accra Floods : Death toll...
#
#                                                Lemma  Subjectivity  Polarity  \
# 0    General News xa loss President Mahama say Ac...      0.525000  0.200000
# 1    SheDeyGoLike MissedThis Photos Many Ghanaian...      0.500000  0.500000
# 2    SheDeyGoLike MissedThis Photos Many Ghanaian...      0.500000  0.500000
# 3    General News xa year old student die Accra f...      0.416667  0.166667
# 4    General News xa Accra Floods Death toll twin...      0.525000  0.200000
#
#    Analysis
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive

# %%
#Check the 'text' and 'airline_sentiment' column

reviews = data[['Lemma', 'Analysis']]

reviews.head()
# Out:
#                                                Lemma  Analysis
# 0    General News xa loss President Mahama say Ac...  Positive
# 1    SheDeyGoLike MissedThis Photos Many Ghanaian...  Positive
# 2    SheDeyGoLike MissedThis Photos Many Ghanaian...  Positive
# 3    General News xa year old student die Accra f...  Positive
# 4    General News xa Accra Floods Death toll twin...  Positive

# %%
#Remove the neutral review rows

reviews = reviews[reviews['Analysis'] != 'Neutral']

reviews.head()
# Out:
#                                                Lemma  Analysis
# 0    General News xa loss President Mahama say Ac...  Positive
# 1    SheDeyGoLike MissedThis Photos Many Ghanaian...  Positive
# 2    SheDeyGoLike MissedThis Photos Many Ghanaian...  Positive
# 3    General News xa year old student die Accra f...  Positive
# 4    General News xa Accra Floods Death toll twin...  Positive

# %%
#Check the values of the 'airline_sentiment' column
reviews['Analysis'].value_counts()
# Out:
# Positive    4936
# Negative    4093
# Name: Analysis, dtype: int64

# %%
#Convert the categorical values to numeric values

sentiment_label = reviews.Analysis.factorize()

sentiment_label
# Out:
# (array([0, 0, 0, ..., 1, 0, 0]),
#  Index(['Positive', 'Negative'], dtype='object'))

# %%
#Retrieve all the text data from the dataset

tweet = reviews.Lemma.values

# %%
#Tokenize (break down into small parts) all the words in the text

tokenizer = Tokenizer(num_words = 5000)

tokenizer.fit_on_texts(tweet)

vocab_size = len(tokenizer.word_index) + 1

# %%
#Replace the words with their assigned numbers
encoded_doc = tokenizer.texts_to_sequences(tweet)

# %%
#Use padding to pad the sentences to have equal length

padded_sequence = pad_sequences(encoded_doc, maxlen = 200)

# %%
#Build the Text Classifier

embedding_vector_length = 32
model = Sequential()
model.add(Embedding(vocab_size, embedding_vector_length, input_length = 200))
model.add(SpatialDropout1D(0.25))
model.add(LSTM(50, dropout = 0.5, recurrent_dropout = 0.5))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 200, 32)           353696
#
#  spatial_dropout1d (SpatialD  (None, 200, 32)          0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 50)                16600
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 370,347
# Trainable params: 370,347
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the sentiment analysis model

history = model.fit(padded_sequence, sentiment_label[0], validation_split=0.2, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 226/226 [==============================] - 61s 254ms/step - loss: 0.7618 - accuracy: 0.6821 - val_loss: 0.5212 - val_accuracy: 0.8095
# Epoch 2/5
# 226/226 [==============================] - 57s 253ms/step - loss: 0.2605 - accuracy: 0.9099 - val_loss: 0.3275 - val_accuracy: 0.8754
# Epoch 3/5
# 226/226 [==============================] - 57s 253ms/step - loss: 0.1663 - accuracy: 0.9452 - val_loss: 0.2801 - val_accuracy: 0.8854
# Epoch 4/5
# 226/226 [==============================] - 58s 255ms/step - loss: 0.1074 - accuracy: 0.9657 - val_loss: 0.2683 - val_accuracy: 0.9003
# Epoch 5/5
# 226/226 [==============================] - 59s 259ms/step - loss: 0.0706 - accuracy: 0.9784 - val_loss: 0.2871 - val_accuracy: 0.8931

# %%
#Accuracy is a metric that generally describes how the model performs across all classes.
#It is useful when all classes are of equal importance.
#It is calculated as the ratio between the number of correct predictions to the total number of predictions.
#The model obtained 95.61% accuracy on the training set and 93.76% accuracy on the test set

# %%
#It is typical to train a deep neural network for multiple epochs. It is also common to randomly shuffle the training data between epochs.
#In the context of machine learning, an epoch is one complete pass through the training data

# %%
#Plot these metrics value accuracy and accuracy

plt.plot(history.history['accuracy'], label = 'accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.legend()
plt.show()

# %%
#Plot these metrics value accuracy and accuracy

plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.legend()
plt.show()

# %%
#Execute sentiment analysis model

def predict_sentiment(text):
    tw = tokenizer.texts_to_sequences([text])
    tw = pad_sequences(tw, maxlen = 200)
    prediction = int(model.predict(tw).round().item())
    print("Predicted Sentiment: ", sentiment_label[1][prediction])

#using these two sentences to execute the model

test1 = "I liked the service provided by the airline."
predict_sentiment(test1)

test2 = "I got the worst service!"
predict_sentiment(test2)
# Out:
# Predicted Sentiment:  Negative
# Predicted Sentiment:  Negative
